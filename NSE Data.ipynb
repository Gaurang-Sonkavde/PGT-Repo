# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
nseurl = "https://en.wikipedia.org/wiki/List_of_companies_listed_on_the_National_Stock_Exchange_of_India"
# nseurl = "https://www.nseindia.com/education/content/reports/eq_research_reports_listed.htm"
data_table = pd.read_html(nseurl)

# %%
data_table
# Out:
# [    0                                                  1
#  0 NaN  This article needs additional citations for ve...,
#              Symbol                              Company name
#  0   NSE: 20MICRONS                        20 Microns Limited
#  1  NSE: 21STCENMGM  21st Century Management Services Limited
#  2  NSE: 3IINFOTECH                       3i Infotech Limited
#  3     NSE: 3MINDIA                          3M India Limited
#  4      NSE: 3PLAND                  3P Land Holdings Limited
#  5     NSE: 3RDROCK               3rd Rock Multimedia Limited
#  6      NSE: 5PAISA                    5Paisa Capital Limited
#  7     NSE: 63MOONS             63 Moons Technologies Limited,
#               Symbol                                Company name
#  0      NSE: AMJUMBO                  A and M Jumbo Bags Limited
#  1      NSE: ABINFRA                      A B Infrabuild Limited
#  2       NSE: ABNINT                     A B N Intercorp Limited
# ...

# %%
len(data_table)
# Out:
# 32

# %%
data_table[1:28]
# Out:
# [            Symbol                              Company name
#  0   NSE: 20MICRONS                        20 Microns Limited
#  1  NSE: 21STCENMGM  21st Century Management Services Limited
#  2  NSE: 3IINFOTECH                       3i Infotech Limited
#  3     NSE: 3MINDIA                          3M India Limited
#  4      NSE: 3PLAND                  3P Land Holdings Limited
#  5     NSE: 3RDROCK               3rd Rock Multimedia Limited
#  6      NSE: 5PAISA                    5Paisa Capital Limited
#  7     NSE: 63MOONS             63 Moons Technologies Limited,
#               Symbol                                Company name
#  0      NSE: AMJUMBO                  A and M Jumbo Bags Limited
#  1      NSE: ABINFRA                      A B Infrabuild Limited
#  2       NSE: ABNINT                     A B N Intercorp Limited
#  3     NSE: A2ZINFRA               A2Z Infra Engineering Limited
#  4       NSE: AAKASH         Aakash Exploration Services Limited
# ...

# %%
df1 = data_table[1]['Symbol']

# %%
df2 = data_table[2]['Symbol']

# %%
df3 = data_table[3]['Symbol']

# %%
df4 = data_table[4]['Symbol']

# %%
df5 = data_table[5]['Symbol']

# %%
df6 = data_table[6]['Symbol']

# %%
df7 = data_table[7]['Symbol']

# %%
df8 = data_table[8]['Symbol']

# %%
df9 = data_table[9]['Symbol']

# %%
df10 = data_table[10]['Symbol']

# %%
df11 = data_table[11]['Symbol']

# %%
df12 = data_table[12]['Symbol']

# %%
df13 = data_table[13]['Symbol']

# %%
df14 = data_table[14]['Symbol']

# %%
df15 = data_table[15]['Symbol']

# %%
df16 = data_table[16]['Symbol']

# %%
df17 = data_table[17]['Symbol']

# %%
df18 = data_table[18]['Symbol']

# %%
df19 = data_table[19]['Symbol']

# %%
df20 = data_table[20]['Symbol']

# %%
df21 = data_table[21]['Symbol']

# %%
df22 = data_table[22]['Symbol']

# %%
df23 = data_table[23]['Symbol']

# %%
df24 = data_table[24]['Symbol']

# %%
df25 = data_table[25]['Symbol']

# %%
df26 = data_table[26]['Symbol']

# %%
df27 = data_table[27]['Symbol']

# %%
df27
# Out:
# 0           NSE: ZEEL
# 1       NSE: ZEELEARN
# 2       NSE: ZEEMEDIA
# 3         NSE: ZENTEC
# 4      NSE: ZENITHBIR
# 5     NSE: ZENITHEXPO
# 6     NSE: ZENSARTECH
# 7          NSE: ZICOM
# 8     NSE: ZODIACLOTH
# 9         NSE: ZODIAC
# 10     NSE: ZODJRDMKJ
# 11          NSE: ZOTA
# 12         NSE: ZUARI
# 13     NSE: ZUARIGLOB
# 14     NSE: ZYDUSWELL
# Name: Symbol, dtype: object

# %%
frames = [df1, df2, df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27]

# %%
nal_df = pd.concat(frames)

# %%
nal_df
# Out:
# 0      NSE: 20MICRONS
# 1     NSE: 21STCENMGM
# 2     NSE: 3IINFOTECH
# 3        NSE: 3MINDIA
# 4         NSE: 3PLAND
#            ...
# 10     NSE: ZODJRDMKJ
# 11          NSE: ZOTA
# 12         NSE: ZUARI
# 13     NSE: ZUARIGLOB
# 14     NSE: ZYDUSWELL
# Name: Symbol, Length: 1808, dtype: object

# %%
final_df = pd.concat((nal_df,nal_df.rename('Symbol1')),axis=1)

# %%
final_df
# Out:
#              Symbol          Symbol1
# 0    NSE: 20MICRONS   NSE: 20MICRONS
# 1   NSE: 21STCENMGM  NSE: 21STCENMGM
# 2   NSE: 3IINFOTECH  NSE: 3IINFOTECH
# 3      NSE: 3MINDIA     NSE: 3MINDIA
# 4       NSE: 3PLAND      NSE: 3PLAND
# ..              ...              ...
# 10   NSE: ZODJRDMKJ   NSE: ZODJRDMKJ
# 11        NSE: ZOTA        NSE: ZOTA
# 12       NSE: ZUARI       NSE: ZUARI
# 13   NSE: ZUARIGLOB   NSE: ZUARIGLOB
# 14   NSE: ZYDUSWELL   NSE: ZYDUSWELL
#
# [1808 rows x 2 columns]

# %%
Dat_tab = final_df["Symbol1"].str.replace("NSE:\xa0","")

# %%
Dat_tab
# Out:
# 0      20MICRONS
# 1     21STCENMGM
# 2     3IINFOTECH
# 3        3MINDIA
# 4         3PLAND
#          ...
# 10     ZODJRDMKJ
# 11          ZOTA
# 12         ZUARI
# 13     ZUARIGLOB
# 14     ZYDUSWELL
# Name: Symbol1, Length: 1808, dtype: object

# %%
tickers = Dat_tab.tolist()

# %%
tickers
# Out:
# ['20MICRONS',
#  '21STCENMGM',
#  '3IINFOTECH',
#  '3MINDIA',
#  '3PLAND',
#  '3RDROCK',
#  '5PAISA',
#  '63MOONS',
#  'AMJUMBO',
#  'ABINFRA',
#  'ABNINT',
#  'A2ZINFRA',
#  'AAKASH',
#  'AARON',
#  'AARTIDRUGS',
#  'AARTIIND',
#  'AARVEEDEN',
#  'AARVI',
#  'AAVAS',
#  'ABAN',
#  'ABB',
#  'POWERINDIA',
#  'ABMINTLTD',
#  'ACC',
#  'ACCELYA',
#  'ACCORD',
#  'ACCURACY',
#  'ACEINTEG',
#  'ACE',
#  'ADANIENT',
#  'ADANIGAS',
#  'ADANIGREEN',
#  'ADANIPORTS',
#  'ADANIPOWER',
#  'ADANITRANS',
#  'ADFFOODS',
#  'ADHUNIKIND',
#  'ABCAPITAL',
#  'ABFRL',
#  'BIRLAMONEY',
#  'ADLABS',
#  'ADORWELD',
#  'ADROITINFO',
#  'ADVENZYMES',
#  'ADVANIHOTR',
#  'AEGISCHEM',
#  'AFFLE',
#  'AGARIND',
#  'AGCNET',
#  'AGRITECH',
#  'AGROPHOS',
#  'ATFL',
#  'AHIMSA',
#  'AHLADA',
#  'AHLUCONT',
#  'AIAENG',
#  'AIRAN',
#  'AIROLAM',
#  'AJANTPHARM',
#  'AJMERA',
#  'AJOONI',
#  'AKASH',
#  'AKG',
#  'AKSHOPTFBR',
#  'AKSHARCHEM',
#  'AKZOINDIA',
#  'ALANKIT',
#  'ALBERTDAVD',
#  'ALCHEM',
# ...

# %%
ticker =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [146], in <cell line: 1>()
# ----> 1 ticker = tickers + "NS"
#
# TypeError: can only concatenate list (not "str") to list

# %%
ticker = [tick for tick in tickers+".NS"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [145], in <cell line: 1>()
# ----> 1 ticker = [tick for tick in tickers+".NS"]
#
# TypeError: can only concatenate list (not "str") to list

# %%
len(tickers)
# Out:
# 1808

# %%
snp_price = yf.download(tickers, start = '2022-05-02', end = '2022-05-05')['Adj Close']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [147], in <cell line: 1>()
# ----> 1 snp_price = yf.download(tickers+"NS", start = '2022-05-02', end = '2022-05-05')['Adj Close']
#
# TypeError: can only concatenate list (not "str") to list

# %%
snp_price.isna().any()

# %%
len(final_df)
# Out:
# 1808

# %%
for word in final_df:
    results = word.replace('NSE:\xa0', '')
    print(results)
# Out:
# 20MICRONS
# 21STCENMGM
# 3IINFOTECH
# 3MINDIA
# 3PLAND
# 3RDROCK
# 5PAISA
# 63MOONS
# AMJUMBO
# ABINFRA
# ABNINT
# A2ZINFRA
# AAKASH
# AARON
# AARTIDRUGS
# AARTIIND
# AARVEEDEN
# AARVI
# AAVAS
# ABAN
# ABB
# POWERINDIA
# ABMINTLTD
# ACC
# ACCELYA
# ACCORD
# ACCURACY
# ACEINTEG
# ACE
# ADANIENT
# ADANIGAS
# ADANIGREEN
# ADANIPORTS
# ADANIPOWER
# ADANITRANS
# ADFFOODS
# ADHUNIKIND
# ABCAPITAL
# ABFRL
# BIRLAMONEY
# ADLABS
# ADORWELD
# ADROITINFO
# ADVENZYMES
# ADVANIHOTR
# AEGISCHEM
# AFFLE
# AGARIND
# AGCNET
# AGRITECH
# AGROPHOS
# ATFL
# AHIMSA
# AHLADA
# AHLUCONT
# AIAENG
# AIRAN
# AIROLAM
# AJANTPHARM
# AJMERA
# AJOONI
# AKASH
# AKG
# AKSHOPTFBR
# AKSHARCHEM
# AKZOINDIA
# ALANKIT
# ALBERTDAVD
# ALCHEM
# ALEMBICLTD
# APLLTD
# ALICON
# ALKALI
# ALKEM
# ALKYLAMINE
# ALLCARGO
# ADSL
# ALLSEC
# ALMONDZ
# ALOKINDS
# ALPA
# ALPHAGEO
# ALPSINDUS
# AMARAJABAT
# AMBANIORG
# AMBER
# AMBIKCO
# AMBUJACEM
# AMDIND
# ASIL
# AMJLAND
# AMRUTANJAN
# ANANTRAJ
# ANDHRACEMT
# ANDHRAPAP
# ANGELBRKG
# ...

# %%
len(results)
# Out:
# 9

# %%
ticker = pd.DataFrame({'Symbol':results})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 ticker = pd.DataFrame({'Symbol':results})
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
ticker
# Out:
#       Symbol
# 0  ZYDUSWELL

# %%
tickers = results.split()

# %%
tickers
# Out:
# ['ZYDUSWELL']

# %%
len(tickers)
# Out:
# 1808

# %%
for word in tickers:
    results = word.replace('NSE:\xa0', '')
    print(results)
# Out:
# 20MICRONS
# 21STCENMGM
# 3IINFOTECH
# 3MINDIA
# 3PLAND
# 3RDROCK
# 5PAISA
# 63MOONS
# AMJUMBO
# ABINFRA
# ABNINT
# A2ZINFRA
# AAKASH
# AARON
# AARTIDRUGS
# AARTIIND
# AARVEEDEN
# AARVI
# AAVAS
# ABAN
# ABB
# POWERINDIA
# ABMINTLTD
# ACC
# ACCELYA
# ACCORD
# ACCURACY
# ACEINTEG
# ACE
# ADANIENT
# ADANIGAS
# ADANIGREEN
# ADANIPORTS
# ADANIPOWER
# ADANITRANS
# ADFFOODS
# ADHUNIKIND
# ABCAPITAL
# ABFRL
# BIRLAMONEY
# ADLABS
# ADORWELD
# ADROITINFO
# ADVENZYMES
# ADVANIHOTR
# AEGISCHEM
# AFFLE
# AGARIND
# AGCNET
# AGRITECH
# AGROPHOS
# ATFL
# AHIMSA
# AHLADA
# AHLUCONT
# AIAENG
# AIRAN
# AIROLAM
# AJANTPHARM
# AJMERA
# AJOONI
# AKASH
# AKG
# AKSHOPTFBR
# AKSHARCHEM
# AKZOINDIA
# ALANKIT
# ALBERTDAVD
# ALCHEM
# ALEMBICLTD
# APLLTD
# ALICON
# ALKALI
# ALKEM
# ALKYLAMINE
# ALLCARGO
# ADSL
# ALLSEC
# ALMONDZ
# ALOKINDS
# ALPA
# ALPHAGEO
# ALPSINDUS
# AMARAJABAT
# AMBANIORG
# AMBER
# AMBIKCO
# AMBUJACEM
# AMDIND
# ASIL
# AMJLAND
# AMRUTANJAN
# ANANTRAJ
# ANDHRACEMT
# ANDHRAPAP
# ANGELBRKG
# ...

# %%
len(results)
# Out:
# 9

# %%
# for i in range(len(tickers)):
#     if tickers[i] == 'NSE:\xa0':
# tickers = tickers.replace('NSE:\xa0' + i + ' ')
new_list = [element.replace('l', '_') for element in my_list]
#     else:
#         continue
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [187], in <cell line: 3>()
#       1 # for i in range(len(tickers)):
#       2 #     if tickers[i] == 'NSE:\xa0':
# ----> 3 tickers = tickers.replace('NSE:\xa0' + i + ' ')
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
tickers =
# Out:
# ['NSE:\xa020MICRONS',
#  'NSE:\xa021STCENMGM',
#  'NSE:\xa03IINFOTECH',
#  'NSE:\xa03MINDIA',
#  'NSE:\xa03PLAND',
#  'NSE:\xa03RDROCK',
#  'NSE:\xa05PAISA',
#  'NSE:\xa063MOONS',
#  'NSE:\xa0AMJUMBO',
#  'NSE:\xa0ABINFRA',
#  'NSE:\xa0ABNINT',
#  'NSE:\xa0A2ZINFRA',
#  'NSE:\xa0AAKASH',
#  'NSE:\xa0AARON',
#  'NSE:\xa0AARTIDRUGS',
#  'NSE:\xa0AARTIIND',
#  'NSE:\xa0AARVEEDEN',
#  'NSE:\xa0AARVI',
#  'NSE:\xa0AAVAS',
#  'NSE:\xa0ABAN',
#  'NSE:\xa0ABB',
#  'NSE:\xa0POWERINDIA',
#  'NSE:\xa0ABMINTLTD',
#  'NSE:\xa0ACC',
#  'NSE:\xa0ACCELYA',
#  'NSE:\xa0ACCORD',
#  'NSE:\xa0ACCURACY',
#  'NSE:\xa0ACEINTEG',
#  'NSE:\xa0ACE',
#  'NSE:\xa0ADANIENT',
#  'NSE:\xa0ADANIGAS',
#  'NSE:\xa0ADANIGREEN',
#  'NSE:\xa0ADANIPORTS',
#  'NSE:\xa0ADANIPOWER',
#  'NSE:\xa0ADANITRANS',
#  'NSE:\xa0ADFFOODS',
#  'NSE:\xa0ADHUNIKIND',
#  'NSE:\xa0ABCAPITAL',
#  'NSE:\xa0ABFRL',
#  'NSE:\xa0BIRLAMONEY',
#  'NSE:\xa0ADLABS',
#  'NSE:\xa0ADORWELD',
#  'NSE:\xa0ADROITINFO',
#  'NSE:\xa0ADVENZYMES',
# ...

# %%
# initializing sub list
sub_list = ["NSE:\xa0"]
 
# Remove substring list from String
# Using loop + replace()
for sub in sub_list:
    test_str = test_str.replace(' ' + sub + ' ', ' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [181], in <cell line: 6>()
#       4 # Remove substring list from String
#       5 # Using loop + replace()
#       6 for sub in sub_list:
# ----> 7     test_str = tickers.replace(' ' + sub + ' ', ' ')
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
print(tickers)
# Out:
# ['NSE:\xa020MICRONS', 'NSE:\xa021STCENMGM', 'NSE:\xa03IINFOTECH', 'NSE:\xa03MINDIA', 'NSE:\xa03PLAND', 'NSE:\xa03RDROCK', 'NSE:\xa05PAISA', 'NSE:\xa063MOONS', 'NSE:\xa0AMJUMBO', 'NSE:\xa0ABINFRA', 'NSE:\xa0ABNINT', 'NSE:\xa0A2ZINFRA', 'NSE:\xa0AAKASH', 'NSE:\xa0AARON', 'NSE:\xa0AARTIDRUGS', 'NSE:\xa0AARTIIND', 'NSE:\xa0AARVEEDEN', 'NSE:\xa0AARVI', 'NSE:\xa0AAVAS', 'NSE:\xa0ABAN', 'NSE:\xa0ABB', 'NSE:\xa0POWERINDIA', 'NSE:\xa0ABMINTLTD', 'NSE:\xa0ACC', 'NSE:\xa0ACCELYA', 'NSE:\xa0ACCORD', 'NSE:\xa0ACCURACY', 'NSE:\xa0ACEINTEG', 'NSE:\xa0ACE', 'NSE:\xa0ADANIENT', 'NSE:\xa0ADANIGAS', 'NSE:\xa0ADANIGREEN', 'NSE:\xa0ADANIPORTS', 'NSE:\xa0ADANIPOWER', 'NSE:\xa0ADANITRANS', 'NSE:\xa0ADFFOODS', 'NSE:\xa0ADHUNIKIND', 'NSE:\xa0ABCAPITAL', 'NSE:\xa0ABFRL', 'NSE:\xa0BIRLAMONEY', 'NSE:\xa0ADLABS', 'NSE:\xa0ADORWELD', 'NSE:\xa0ADROITINFO', 'NSE:\xa0ADVENZYMES', 'NSE:\xa0ADVANIHOTR', 'NSE:\xa0AEGISCHEM', 'NSE:\xa0AFFLE', 'NSE:\xa0AGARIND', 'NSE:\xa0AGCNET', 'NSE:\xa0AGRITECH', 'NSE:\xa0AGROPHOS', '
# ...

# %%
print(tickers.replace('NSE:\xa0', ''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
# ----> 1 print(tickers.replace('NSE:\xa0', ''))
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
yf.download('20MICRONS',start ='2022-05-02', end = '2022-05-05')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 20MICRONS: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
snp_price = yf.download(tickers,start ='2022-05-02', end = '2022-05-05')['Adj Close']
# Out:
# [*********************100%***********************]  1808 of 1808 completedd
#
# 1808 Failed downloads:
# - NSE: MODIRUBBER: No data found for this date range, symbol may be delisted
# - NSE: SPENTEX: No data found for this date range, symbol may be delisted
# - NSE: BKMINDST: No data found for this date range, symbol may be delisted
# - NSE: KAMATHOTEL: No data found for this date range, symbol may be delisted
# - NSE: JSL: No data found for this date range, symbol may be delisted
# - NSE: BINDALAGRO: No data found for this date range, symbol may be delisted
# - NSE: SADBHAV: No data found for this date range, symbol may be delisted
# - NSE: BATAINDIA: No data found for this date range, symbol may be delisted
# - NSE: AIROLAM: No data found for this date range, symbol may be delisted
# - NSE: MANGTIMBER: No data found for this date range, symbol may be delisted
# - NSE: RGL: No data found for this date range, symbol may be delisted
# ...
